# %%
class Node:
    def __init__(self,x,y,name):
        self.name = name
        self.x = x
        self.y = y
        
    def displayNodeDetails(self):
        print("\nName : ",self.name,"\x : ",self.x,"\y : ",self.y,"\n")
        
class Edge:
    def __init__(self,v1,v2, length, width,terrain, traffic, disaster,weight,cost,benefit):
        for village in 
        self.v1 = v1
        self.v2 = v2
        self.length = length
        self.width = width
        self.terrain = terrain
        self.traffic = traffic
        self.disaster = disaster
    def displayEdgeDetails(self):
        print("\nv1 : ",self.v1,"\nv2 : ",self.v2,"\nlength : ",self.length,"\nwidth : ",self.width,"\nterrain : ",self.terrain,"\ntraffic : ",self.traffic,"\ndisaster : ",self.disaster)

class Graph:
    def __init__(self):
        #self.visited = []
        #self.selected = []
        self.nodes = []
        self.edges = []
    def addNode(self,factors):
        temp = Node(factors[0],factors[1],factors[2],factors[3],factors[4],factors[5])
        self.nodes.append(temp)
    def addEdge(self,factors):
        temp = Edge(factors[0],factors[1],factors[2],factors[3],factors[4],factors[5],factors[6])
        self.edges.append(temp)
    def listNodes(self):
        for node in self.nodes:
            node.displayNodeDetails()
    def listEdges(self):
        for edge in self.edges:
            edge.displayEdgeDetails()

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
 
for edge in g.edges:
    x=[edge.v1.x,edge.v2.x]
    y=[edge.v1.y,edge.v2.y]
    name=edge.v1+edge.v2
    plt.plot(x,y,label=)

# line 1 points
x1 = [1,2,3]
y1 = [2,4,1]
# plotting the line 1 points 
plt.plot(x1, y1, label = "line 1")
 
# line 2 points
x2 = [1,2,3]
y2 = [4,1,3]
# plotting the line 2 points 
plt.plot(x2, y2, label = "line 2")
 
# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Two lines on same graph!')
 
# show a legend on the plot
plt.legend()
 
# function to show the plot
plt.show()
